# %% [markdown]
# <a href="https://colab.research.google.com/github/aleksejalex/PyPEF_internal/blob/main/ELLS_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ELLS - Practical Introduction into Programming with Python
#
# <a href="https://pef.czu.cz/en/"><img src="https://aleksejalex.4fan.cz/ells/temp_banner.jpeg" alt="banner" width="1000"></a>

# %% [markdown]
# [GitHub Repository](https://github.com/aleksejalex/2024_ells_python)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn

# %% [markdown]
# ## import dataset

# %%
url_to_data = "https://gist.githubusercontent.com/aleksejalex/26a83646c03120af1eaeb117572d895e/raw/2ddc8661d86fbf1b7d09204ff39fdf74ce3723b6/cereals.csv"

df_cereals = pd.read_csv(url_to_data, delimiter=',')
df_cereals.sample(20)
# Out:
#                            name mfr type_of  calories  protein  fat  sodium  \
# 43                        Maypo   A       H       100        4    1       0
# 57               Quaker Oatmeal   Q       H       100        5    2       0
# 63               Shredded Wheat   N       C        80        2    0       0
# 7                       Basic 4   G       C       130        3    2     210
# 31               Golden Grahams   G       C       110        1    1     280
# 75                     Wheaties   G       C       100        3    1     200
# 34           Great Grains Pecan   P       C       120        3    3      75
# 29               Fruity Pebbles   P       C       110        1    1     135
# 0                     100% Bran   N       C        70        4    1     130
# 23                  Double Chex   R       C       100        2    0     190
# 13                     Clusters   G       C       110        3    2     140
# 38  Just Right Crunchy  Nuggets   K       C       110        2    1     170
# 52        Post Nat. Raisin Bran   P       C       120        3    1     200
# 47         Multi-Grain Cheerios   G       C       100        2    1     220
# 73                         Trix   G       C       110        1    1     140
# 12        Cinnamon Toast Crunch   G       C       120        1    3     210
# 54                  Puffed Rice   Q       C        50        1    0       0
# 25               Frosted Flakes   K       C       110        1    0     200
# 48             Nut&Honey Crunch   K       C       120        2    1     190
# 14                  Cocoa Puffs   G       C       110        1    1     180
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 43    0.0   16.0       3      95        25      2    1.00  1.00  54.850917
# 57    2.7   -1.0      -1     110         0      1    1.00  0.67  50.828392
# 63    3.0   16.0       0      95         0      1    0.83  1.00  68.235885
# 7     2.0   18.0       8     100        25      3    1.33  0.75  37.038562
# 31    0.0   15.0       9      45        25      2    1.00  0.75  23.804043
# 75    3.0   17.0       3     110        25      1    1.00  1.00  51.592193
# 34    3.0   13.0       4     100        25      3    1.00  0.33  45.811716
# 29    0.0   13.0      12      25        25      2    1.00  0.75  28.025765
# 0    10.0    5.0       6     280        25      3    1.00  0.33  68.402973
# 23    1.0   18.0       5      80        25      3    1.00  0.75  44.330856
# 13    2.0   13.0       7     105        25      3    1.00  0.50  40.400208
# 38    1.0   17.0       6      60       100      3    1.00  1.00  36.523683
# 52    6.0   11.0      14     260        25      3    1.33  0.67  37.840594
# 47    2.0   15.0       6      90        25      1    1.00  1.00  40.105965
# 73    0.0   13.0      12      25        25      2    1.00  1.00  27.753301
# 12    0.0   13.0       9      45        25      2    1.00  0.75  19.823573
# 54    0.0   13.0       0      15         0      3    0.50  1.00  60.756112
# 25    1.0   14.0      11      25        25      1    1.00  0.75  31.435973
# 48    0.0   15.0       9      40        25      2    1.00  0.67  29.924285
# 14    0.0   12.0      13      55        25      2    1.00  1.00  22.736446

# %%
df_cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type_of   77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df_cereals.describe(include='all')
# Out:
#              name  mfr type_of    calories    protein        fat      sodium  \
# count          77   77      77   77.000000  77.000000  77.000000   77.000000
# unique         77    7       2         NaN        NaN        NaN         NaN
# top     100% Bran    K       C         NaN        NaN        NaN         NaN
# freq            1   23      74         NaN        NaN        NaN         NaN
# mean          NaN  NaN     NaN  106.883117   2.545455   1.012987  159.675325
# std           NaN  NaN     NaN   19.484119   1.094790   1.006473   83.832295
# min           NaN  NaN     NaN   50.000000   1.000000   0.000000    0.000000
# 25%           NaN  NaN     NaN  100.000000   2.000000   0.000000  130.000000
# 50%           NaN  NaN     NaN  110.000000   3.000000   1.000000  180.000000
# 75%           NaN  NaN     NaN  110.000000   3.000000   2.000000  210.000000
# max           NaN  NaN     NaN  160.000000   6.000000   5.000000  320.000000
#
#             fiber      carbo     sugars      potass    vitamins      shelf  \
# count   77.000000  77.000000  77.000000   77.000000   77.000000  77.000000
# unique        NaN        NaN        NaN         NaN         NaN        NaN
# top           NaN        NaN        NaN         NaN         NaN        NaN
# freq          NaN        NaN        NaN         NaN         NaN        NaN
# mean     2.151948  14.597403   6.922078   96.077922   28.246753   2.207792
# std      2.383364   4.278956   4.444885   71.286813   22.342523   0.832524
# min      0.000000  -1.000000  -1.000000   -1.000000    0.000000   1.000000
# 25%      1.000000  12.000000   3.000000   40.000000   25.000000   1.000000
# 50%      2.000000  14.000000   7.000000   90.000000   25.000000   2.000000
# 75%      3.000000  17.000000  11.000000  120.000000   25.000000   3.000000
# max     14.000000  23.000000  15.000000  330.000000  100.000000   3.000000
#
#            weight       cups     rating
# count   77.000000  77.000000  77.000000
# unique        NaN        NaN        NaN
# top           NaN        NaN        NaN
# freq          NaN        NaN        NaN
# mean     1.029610   0.821039  42.665705
# std      0.150477   0.232716  14.047289
# min      0.500000   0.250000  18.042851
# 25%      1.000000   0.670000  33.174094
# 50%      1.000000   0.750000  40.400208
# 75%      1.000000   1.000000  50.828392
# max      1.500000   1.500000  93.704912

# %%
sns.pairplot(data=df_cereals)

# %%
plt.plot(df_cereals['fiber'], df_cereals['rating'], '.')
plt.show()

# %% [markdown]
# <div style="font-style: italic; font-size: 14px;">
#     <p>This material was prepared by Department of Information Engineering (<a href="https://www.pef.czu.cz/en">PEF ČZU</a>) exclusively for purposes of ELLS summer school "Practical Introduction into Programming with Python". Any distribution or reproduction of this material, in whole or in part, without prior written consent of the authors is prohibited.</p>
#     <p>This material is shared under the <b>Creative Commons Attribution-NonCommercial-NoDerivatives 4.0 International Public License</b>, <a href="https://creativecommons.org/licenses/by-nc-nd/4.0/">link</a>.</p>
# </div>

# %% [markdown]
# `
# #Scale the input features to have zero mean and unit variance
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# `
